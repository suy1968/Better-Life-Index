# %% [markdown]
# ## Better Life Index

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()

# %%
data = pd.read_csv(r'C:\Users\HP\Desktop\BetterLifeIndex2015.csv')

# %%
data.head()
# Out:
#      Country    Dwellings without basic facilities    Housing expenditure  \
# 0  Australia                                   1.1                     20
# 1    Austria                                   1.0                     21
# 2    Belgium                                   2.0                     21
# 3     Canada                                   0.2                     21
# 4      Chile                                   9.4                     18
#
#      Rooms per person    Household net adjusted disposable income  \
# 0                 2.3                                       31588
# 1                 1.6                                       31173
# 2                 2.2                                       28307
# 3                 2.5                                       29365
# 4                 1.2                                       14533
#
#      Household net financial wealth    Employment rate    Job security  \
# ...

# %%
data.shape
# Out:
# (36, 25)

# %%
data.describe()
# Out:
#          Dwellings without basic facilities    Housing expenditure  \
# count                             36.000000              36.000000
# mean                               2.533333              20.833333
# std                                3.750581               2.843539
# min                                0.000000              11.000000
# 25%                                0.200000              19.750000
# 50%                                0.800000              21.000000
# 75%                                3.825000              22.000000
# max                               15.100000              26.000000
#
#          Rooms per person    Household net adjusted disposable income  \
# count           36.000000                                   36.000000
# mean             1.661111                                24121.722222
# std              0.432453                                 7273.211307
# min              0.900000                                11664.000000
# ...

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'  Dwellings without basic facilities'}>,
#         <AxesSubplot:title={'center':'  Housing expenditure'}>,
#         <AxesSubplot:title={'center':'  Rooms per person'}>,
#         <AxesSubplot:title={'center':'  Household net adjusted disposable income'}>,
#         <AxesSubplot:title={'center':'  Household net financial wealth'}>],
#        [<AxesSubplot:title={'center':'  Employment rate'}>,
#         <AxesSubplot:title={'center':'  Job security'}>,
#         <AxesSubplot:title={'center':'  Long-term unemployment rate'}>,
#         <AxesSubplot:title={'center':'  Personal earnings'}>,
#         <AxesSubplot:title={'center':'  Quality of support network'}>],
#        [<AxesSubplot:title={'center':'  Educational attainment'}>,
#         <AxesSubplot:title={'center':'  Student skills'}>,
#         <AxesSubplot:title={'center':'  Years in education'}>,
#         <AxesSubplot:title={'center':'  Air pollution'}>,
# ...

# %%
data.columns
# Out:
# Index(['Country', '  Dwellings without basic facilities',
#        '  Housing expenditure', '  Rooms per person',
#        '  Household net adjusted disposable income',
#        '  Household net financial wealth', '  Employment rate',
#        '  Job security', '  Long-term unemployment rate',
#        '  Personal earnings', '  Quality of support network',
#        '  Educational attainment', '  Student skills', '  Years in education',
#        '  Air pollution', '  Water quality', '  Consultation on rule-making',
#        '  Voter turnout', '  Life expectancy', '  Self-reported health',
#        '  Life satisfaction', '  Assault rate', '  Homicide rate',
#        '  Employees working very long hours',
#        '  Time devoted to leisure and personal care'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Country                                         object
#   Dwellings without basic facilities           float64
#   Housing expenditure                            int64
#   Rooms per person                             float64
#   Household net adjusted disposable income       int64
#   Household net financial wealth                 int64
#   Employment rate                                int64
#   Job security                                 float64
#   Long-term unemployment rate                  float64
#   Personal earnings                              int64
#   Quality of support network                     int64
#   Educational attainment                         int64
#   Student skills                                 int64
#   Years in education                           float64
#   Air pollution                                  int64
#   Water quality                                  int64
#   Consultation on rule-making                  float64
# ...

# %%
data.sample(7)
# Out:
#      Country    Dwellings without basic facilities    Housing expenditure  \
# 28     Spain                                   0.1                     22
# 3     Canada                                   0.2                     21
# 20    Mexico                                   4.2                     21
# 25  Portugal                                   0.9                     19
# 16     Italy                                   1.1                     24
# 9     France                                   0.5                     21
# 24    Poland                                   3.2                     21
#
#       Rooms per person    Household net adjusted disposable income  \
# 28                 1.9                                       22477
# 3                  2.5                                       29365
# 20                 1.0                                       13085
# 25                 1.6                                       20086
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 25 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Country                                      36 non-null     object
#  1     Dwellings without basic facilities         36 non-null     float64
#  2     Housing expenditure                        36 non-null     int64
#  3     Rooms per person                           36 non-null     float64
#  4     Household net adjusted disposable income   36 non-null     int64
#  5     Household net financial wealth             36 non-null     int64
#  6     Employment rate                            36 non-null     int64
#  7     Job security                               36 non-null     float64
#  8     Long-term unemployment rate                36 non-null     float64
# ...

# %%
data.isnull().sum()
# Out:
# Country                                        0
#   Dwellings without basic facilities           0
#   Housing expenditure                          0
#   Rooms per person                             0
#   Household net adjusted disposable income     0
#   Household net financial wealth               0
#   Employment rate                              0
#   Job security                                 0
#   Long-term unemployment rate                  0
#   Personal earnings                            0
#   Quality of support network                   0
#   Educational attainment                       0
#   Student skills                               0
#   Years in education                           0
#   Air pollution                                0
#   Water quality                                0
#   Consultation on rule-making                  0
#   Voter turnout                                0
#   Life expectancy                              0
# ...

# %%
teju = data.cov()
teju
# Out:
#                                                Dwellings without basic facilities  \
#   Dwellings without basic facilities                                    14.066857
#   Housing expenditure                                                   -5.311429
#   Rooms per person                                                      -0.925238
#   Household net adjusted disposable income                          -15658.481905
#   Household net financial wealth                                    -49569.148571
#   Employment rate                                                       -7.447619
#   Job security                                                          -1.337619
#   Long-term unemployment rate                                           -2.783076
#   Personal earnings                                                 -30151.760000
#   Quality of support network                                            -6.099048
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=36, step=1)

# %%
data.corr()
# Out:
#                                                Dwellings without basic facilities  \
#   Dwellings without basic facilities                                     1.000000
#   Housing expenditure                                                   -0.498028
#   Rooms per person                                                      -0.570448
#   Household net adjusted disposable income                              -0.574017
#   Household net financial wealth                                        -0.407325
#   Employment rate                                                       -0.261606
#   Job security                                                          -0.128987
#   Long-term unemployment rate                                           -0.190820
#   Personal earnings                                                     -0.615876
#   Quality of support network                                            -0.318863
# ...

# %%
sns.heatmap(data.iloc[:,1:].corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data.iloc[:,1:].corr())

# %%
#print 2nd column of third and fourth row 
data.iloc[2:4, 1:2]
# Out:
#      Dwellings without basic facilities
# 2                                   2.0
# 3                                   0.2

# %%
data.plot.barh()
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(teju,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # THANK YOU
